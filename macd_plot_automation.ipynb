# %%
from mod_my_utils.read_write_data import get_price_yahoo
from mod_macd_utils.macd import *

# %%
symbols = ["HDFC", 'RELIANCE', 'TCS', 'HINDUNILVR', 'INFY', 'HDFC', 'BHARTIARTL', 'ITC', 'ASIANPAINT', 'NESTLEIND', 'HCLTECH', 'SBI', 'SBIN']

# %%
symbol = symbols[0]
data_source = "yahoo"
# MM/DD/YYYY
start_date = "1/1/2010"
end_date = "1/1/2015"
datasource = data_source
print(start_date)
print(end_date)
print(symbol)
print(datasource)
# Out:
# 1/1/2010
# 1/1/2015
# HDFC
# yahoo

# %%
data = get_price_yahoo(symbol, data_source, start_date, end_date)
# Out:
# stock name HDFC

# %%
data = data[["Adj Close"]].copy()
data.columns = ["price"]
data.head()
# Out:
#                  price
# Date
# 2010-01-04  442.267761
# 2010-01-05  443.772705
# 2010-01-06  445.905975
# 2010-01-07  437.604156
# 2010-01-08  429.980499

# %%
short_window = 20
long_window = 50
signal_window = 12

# %%
macd_data = get_macd_signal_line(data, short_window, long_window, signal_window)

# %%
macd_data.head()
# Out:
#                  price  SMA  LMA  MACD  signal_line
# Date
# 2010-01-04  442.267761  NaN  NaN   NaN          NaN
# 2010-01-05  443.772705  NaN  NaN   NaN          NaN
# 2010-01-06  445.905975  NaN  NaN   NaN          NaN
# 2010-01-07  437.604156  NaN  NaN   NaN          NaN
# 2010-01-08  429.980499  NaN  NaN   NaN          NaN

# %%
macd_signals_from_mcad = get_signal_macd_crossover(macd_data, long_window)

# %%
macd_signals_from_mcad.head()
# Out:
#                  price  SMA  LMA  MACD  signal_line  buy_sell
# Date
# 2010-01-04  442.267761  NaN  NaN   NaN          NaN       NaN
# 2010-01-05  443.772705  NaN  NaN   NaN          NaN       0.0
# 2010-01-06  445.905975  NaN  NaN   NaN          NaN       0.0
# 2010-01-07  437.604156  NaN  NaN   NaN          NaN       0.0
# 2010-01-08  429.980499  NaN  NaN   NaN          NaN       0.0

# %%
macd_signals_from_signalline = get_signal_macd_signalline(macd_data, long_window)

# %%
macd_signals_from_signalline.head()
# Out:
#                  price  SMA  LMA  MACD  signal_line  buy_sell
# Date
# 2010-01-04  442.267761  NaN  NaN   NaN          NaN       NaN
# 2010-01-05  443.772705  NaN  NaN   NaN          NaN       0.0
# 2010-01-06  445.905975  NaN  NaN   NaN          NaN       0.0
# 2010-01-07  437.604156  NaN  NaN   NaN          NaN       0.0
# 2010-01-08  429.980499  NaN  NaN   NaN          NaN       0.0

# %%
plot_macd_buy_sell(macd_data, macd_signals_from_mcad, symbol = symbol)

# %%
plot_macd_buy_sell(macd_data, macd_signals_from_signalline, symbol = symbol)
